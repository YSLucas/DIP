# %% [markdown]
# # DIP opdracht 2: Letterfrequenties

# %%
import numpy

# %%
placeholder = "In Python, while operating with String, one can do multiple operations on it. Let’s see how to iterate over characters of a string in Python."
# Filter
def filter_for_loop(text):
    """
    """
    for letter in range(0, len(text)):
        print(placeholder[letter] + placeholder[letter + 1])
        
filter_for_loop(placeholder)
# Out:
# In
# n
#  P
# Py
# yt
# th
# ho
# on
# n,
# ,
#  w
# wh
# hi
# il
# le
# e
#  o
# op
# pe
# er
# ra
# at
# ti
# in
# ng
# g
#  w
# wi
# it
# th
# h
#  S
# St
# tr
# ri
# in
# ng
# g,
# ,
#  o
# on
# ne
# e
#  c
# ca
# an
# n
#  d
# do
# o
#  m
# mu
# ul
# lt
# ti
# ip
# pl
# le
# e
#  o
# op
# pe
# er
# ra
# at
# ti
# io
# on
# ns
# s
#  o
# on
# n
#  i
# it
# t.
# .
#  L
# Le
# et
# t’
# ’s
# s
#  s
# se
# ee
# e
#  h
# ho
# ow
# w
#  t
# to
# o
#  i
# it
# te
# er
# ra
# at
# te
# e
#  o
# ov
# ve
# er
# r
#  c
# ch
# ha
# ar
# ra
# ac
# ct
# te
# er
# rs
# s
#  o
# of
# f
#  a
# a
#  s
# st
# tr
# ri
# in
# ng
# g
#  i
# in
# n
#  P
# Py
# yt
# th
# ho
# on
# n.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-71021be62f0f> in <module>
#       7         print(placeholder[letter] + placeholder[letter + 1])
#       8
# ----> 9 filter_for_loop(placeholder)
#
# ...

# %%
az = 'abcdefghijklmnopqrstuvwxyz_%'
def mapper(x):
    print(numpy.zeros((28,28)))

mapper(az)
